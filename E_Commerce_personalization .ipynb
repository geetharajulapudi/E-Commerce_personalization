# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e0ee8581-7395-4cd4-8ec9-d12747410d7b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0ee8581-7395-4cd4-8ec9-d12747410d7b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv
from warnings import filterwarnings
filterwarnings('ignore')

# %%
data = pd.read_csv('amazon.csv')
data
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
data
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
data.tail()
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# ...

# %%
data.shape
# Out:
# (1465, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
data.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
data.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
data = data[data['rating_count'].isnull() == False]
data.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
data['discounted_price'] = data['discounted_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
data['actual_price'] = data['actual_price'].astype(str).str.replace('₹', '').str.replace(',', '').astype(float)
data['discount_percentage'] = data['discount_percentage'].astype(str).str.replace('%','').astype(float)/100

# %%
data
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
# Initial count of rows containing '|'
count_initial = data['rating'].str.contains('\|').sum()
print(f"Total rows containing '|' in 'rating': {count_initial}")

# Filter out rows containing '|'
data = data[~data['rating'].str.contains('\|', na=False)]

# Count again to confirm
count_final = data['rating'].str.contains('\|').sum()
print(f"Total rows containing '|' in 'rating': {count_final}")
# Out:
# Total rows containing '|' in 'rating': 1
# Total rows containing '|' in 'rating': 0

# %%
data['rating'] = data['rating'].astype(str).str.replace(',', '').astype(float)
data['rating_count'] = data['rating_count'].astype(str).str.replace(',', '').astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1462 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1462 non-null   object
#  1   product_name         1462 non-null   object
#  2   category             1462 non-null   object
#  3   discounted_price     1462 non-null   float64
#  4   actual_price         1462 non-null   float64
#  5   discount_percentage  1462 non-null   float64
#  6   rating               1462 non-null   float64
#  7   rating_count         1462 non-null   float64
#  8   about_product        1462 non-null   object
#  9   user_id              1462 non-null   object
#  10  user_name            1462 non-null   object
#  11  review_id            1462 non-null   object
#  12  review_title         1462 non-null   object
#  13  review_content       1462 non-null   object
#  14  img_link             1462 non-null   object
# ...

# %%
data['rating_avg'] = data['rating'] * data['rating_count']

# %%
data['sub_category'] = data['category'].astype(str).str.split('|').str[-1]
data['main_category'] = data['category'].astype(str).str.split('|').str[0]

# %%
data['sub_category']
# Out:
# 0                      USBCables
# 1                      USBCables
# 2                      USBCables
# 3                      USBCables
# 4                      USBCables
#                   ...
# 1460    WaterPurifierAccessories
# 1461           Rice&PastaCookers
# 1462              HeatConvectors
# 1463                 ExhaustFans
# 1464              SandwichMakers
# Name: sub_category, Length: 1462, dtype: object

# %%
data['main_category']
# Out:
# 0       Computers&Accessories
# 1       Computers&Accessories
# 2       Computers&Accessories
# 3       Computers&Accessories
# 4       Computers&Accessories
#                 ...
# 1460             Home&Kitchen
# 1461             Home&Kitchen
# 1462             Home&Kitchen
# 1463             Home&Kitchen
# 1464             Home&Kitchen
# Name: main_category, Length: 1462, dtype: object

# %%
main_category_counts = data['main_category'].value_counts().head(30)

plt.figure(figsize=(10, 6))
main_category_counts.plot(kind='bar',color='salmon')
plt.ylabel('Number of Products')
plt.title('Distribution of Main Category Products (Top 30)')
plt.xticks(rotation=70)
plt.show()

# %%
sub_category_counts = data['sub_category'].value_counts().head(30)

plt.figure(figsize=(10, 6))
sub_category_counts.plot(kind='bar',color='orchid')
plt.ylabel('Number of Products')
plt.title('Distribution of Sub Category Products (Top 30)')
plt.xticks(rotation=70)
plt.show()

# %%
# Display the top 30 main categories as a DataFrame
top_main_categories = main_category_counts.reset_index()
top_main_categories.columns = ['Main Category', 'Number of Products']
print('Top 30 main categories:')
print(top_main_categories)
# Out:
# Top 30 main categories:
#            Main Category  Number of Products
# 0            Electronics                 526
# 1  Computers&Accessories                 451
# 2           Home&Kitchen                 447
# 3         OfficeProducts                  31
# 4     MusicalInstruments                   2
# 5        HomeImprovement                   2
# 6             Toys&Games                   1
# 7          Car&Motorbike                   1
# 8    Health&PersonalCare                   1

# %%
# Display the top 30 main categories as a DataFrame
top_sub_categories = sub_category_counts.reset_index()
top_sub_categories.columns = ['Sub Category', 'Number of Products']
print('Top 30 Sub categories:')
print(top_sub_categories)
# Out:
# Top 30 Sub categories:
#                 Sub Category  Number of Products
# 0                  USBCables                 231
# 1               SmartWatches                  76
# 2                Smartphones                  68
# 3           SmartTelevisions                  63
# 4                     In-Ear                  52
# 5             RemoteControls                  49
# 6              MixerGrinders                  27
# 7                 HDMICables                  24
# 8                   DryIrons                  24
# 9                       Mice                  24
# 10       InstantWaterHeaters                  23
# 11               LintShavers                  22
# 12                FanHeaters                  20
# 13           ElectricHeaters                  20
# 14           ElectricKettles                  19
# 15              HandBlenders                  19
# 16       WirelessUSBAdapters                  18
# 17              WallChargers                  16
# ...

# %%
plt.hist(data['rating'], edgecolor='black', color='skyblue')
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Customer Ratings')
plt.show()

# %%
# Create table with values per cluster
rating_bins = [0, 1, 2, 3, 4, 5]  # Define bin edges
data['rating_bin'] = pd.cut(data['rating'], bins=rating_bins, include_lowest=True, labels=['0-1', '1-2', '2-3', '3-4', '4-5'])

# Count the number of reviews in each rating bin
rating_distribution = data['rating_bin'].value_counts().sort_index().reset_index()
rating_distribution.columns = ['Rating Range', 'Number of Reviews']

print('Rating Distribution Table:')
print(rating_distribution)
# Out:
# Rating Distribution Table:
#   Rating Range  Number of Reviews
# 0          0-1                  0
# 1          1-2                  1
# 2          2-3                  8
# 3          3-4                525
# 4          4-5                928

# %%
top_categories = data.groupby('main_category')['rating'].mean().sort_values(ascending=False).head(10).reset_index()
top_categories.columns = ['Category', 'Average Rating']

plt.figure(figsize=(10, 6))
plt.bar(top_categories['Category'], top_categories['Average Rating'], color='pink')

plt.xlabel('Category')
plt.ylabel('Average Rating')
plt.title('Top Categories by Average Rating')

plt.xticks(rotation=70)

plt.show()

# %%
ranking = data.groupby('main_category')['rating'].mean().sort_values(ascending=False).reset_index()
print(ranking)
# Out:
#            main_category    rating
# 0         OfficeProducts  4.309677
# 1             Toys&Games  4.300000
# 2        HomeImprovement  4.250000
# 3  Computers&Accessories  4.155654
# 4            Electronics  4.081749
# 5           Home&Kitchen  4.040716
# 6    Health&PersonalCare  4.000000
# 7     MusicalInstruments  3.900000
# 8          Car&Motorbike  3.800000

# %%
top = data.groupby(['sub_category'])['rating'].mean().sort_values(ascending=False).head(10).reset_index()

plt.figure(figsize=(10, 6))
plt.bar(top['sub_category'], top['rating'])

plt.xlabel('sub_category')
plt.ylabel('Rating')
plt.title('Top sub category by Rating')

plt.xticks(rotation=70)

plt.show()

# %%
ranking = data.groupby('sub_category')['rating'].mean().sort_values(ascending=False).reset_index()
print(ranking)
# Out:
#                         sub_category  rating
# 0                            Tablets     4.6
# 1                               Film     4.5
# 2                             Memory     4.5
# 3    SmallApplianceParts&Accessories     4.5
# 4                   StreamingClients     4.5
# ..                               ...     ...
# 202                   InkjetPrinters     3.6
# 203                       PCHeadsets     3.5
# 204                        3DGlasses     3.5
# 205                       DustCovers     3.4
# 206                 ElectricGrinders     3.3
#
# [207 rows x 2 columns]

# %%
average_discount_by_maincategory = data.groupby('main_category')['discount_percentage'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(average_discount_by_maincategory.index, average_discount_by_maincategory.values, color='lightgreen')
plt.title('Average Discount Percentage by Main Category')
plt.xlabel('Category')
plt.ylabel('Average Discount Percentage')
plt.xticks(rotation=70)
plt.show()

# %%
table = pd.DataFrame({'Main Category': average_discount_by_maincategory.index, 'Mean Discount Percentage': average_discount_by_maincategory.values})
print(table)
# Out:
#            Main Category  Mean Discount Percentage
# 0        HomeImprovement                  0.575000
# 1  Computers&Accessories                  0.539202
# 2    Health&PersonalCare                  0.530000
# 3            Electronics                  0.508289
# 4     MusicalInstruments                  0.460000
# 5          Car&Motorbike                  0.420000
# 6           Home&Kitchen                  0.401745
# 7         OfficeProducts                  0.123548
# 8             Toys&Games                  0.000000

# %%
average_discount_by_subcategory = data.groupby('sub_category')['discount_percentage'].mean().head(15).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(average_discount_by_subcategory.index, average_discount_by_subcategory.values, color='grey')
plt.title('Average Discount Percentage by Sub Category')
plt.xlabel('Category')
plt.ylabel('Average Discount Percentage')
plt.xticks(rotation=80)
plt.show()

# %%
table = pd.DataFrame({'Main Category': average_discount_by_subcategory.index, 'Mean Discount Percentage': average_discount_by_subcategory.values})
print(table)
# Out:
#              Main Category  Mean Discount Percentage
# 0                 Adapters                  0.803333
# 1      Bedstand&DeskMounts                  0.745000
# 2               BasicCases                  0.707500
# 3       AutomobileChargers                  0.580000
# 4   Adapters&Multi-Outlets                  0.570000
# 5        BluetoothSpeakers                  0.485000
# 6       BackgroundSupports                  0.460000
# 7                AirFryers                  0.440000
# 8    AirPurifiers&Ionizers                  0.420000
# 9   AVReceivers&Amplifiers                  0.360000
# 10       BluetoothAdapters                  0.330000
# 11         BatteryChargers                  0.250000
# 12               3DGlasses                  0.230000
# 13            BasicMobiles                  0.185556
# 14                   Basic                  0.000000

# %%
numeric_cols = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_cols.corr()

print(correlation_matrix)
# Out:
#                      discounted_price  actual_price  discount_percentage  \
# discounted_price             1.000000      0.961910            -0.242298
# actual_price                 0.961910      1.000000            -0.117855
# discount_percentage         -0.242298     -0.117855             1.000000
# rating                       0.121132      0.122467            -0.155679
# rating_count                -0.027304     -0.036215             0.011294
# rating_avg                  -0.027039     -0.035959             0.010701
#
#                        rating  rating_count  rating_avg
# discounted_price     0.121132     -0.027304   -0.027039
# actual_price         0.122467     -0.036215   -0.035959
# discount_percentage -0.155679      0.011294    0.010701
# rating               1.000000      0.102235    0.115217
# rating_count         0.102235      1.000000    0.999061
# rating_avg           0.115217      0.999061    1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data['product_id_encoded'] = le.fit_transform(data['product_id'])

# Create a new dataframe with the user_id frequency table
ftable = pd.DataFrame({'Product ID': data['product_id_encoded'].value_counts().index, 'Frequency': data['product_id_encoded'].value_counts().values})

# Display the dataframe
print(ftable)
id_ex = ftable.iloc[0,0]
print(id_ex)
# Out:
#       Product ID  Frequency
# 0            346          3
# 1            938          3
# 2            172          3
# 3            519          3
# 4            711          3
# ...          ...        ...
# 1343         820          1
# 1344        1157          1
# 1345        1337          1
# 1346        1072          1
# 1347         134          1
#
# [1348 rows x 2 columns]
# 346

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def recommend_products(data, product_id_encoded):
    # Use TfidfVectorizer to transform the product descriptions into numerical feature vectors
    tfidf = TfidfVectorizer(stop_words='english')
    data['about_product'] = data['about_product'].fillna('')  # fill NaN values with empty string
    tfidf_matrix = tfidf.fit_transform(data['about_product'])

    # Get the purchase history for the user
    product_history = data[data['product_id_encoded'] == product_id_encoded]

    # Use cosine_similarity to calculate the similarity between each pair of product descriptions
    # only for the products that the user has already purchased
    indices = product_history.index.tolist()

    if indices:
        # Create a new similarity matrix with only the rows and columns for the purchased products
        cosine_sim_user = cosine_similarity(tfidf_matrix[indices], tfidf_matrix)

        # Create a pandas Series with product indices as the index and product names as the values
        products = data.iloc[indices]['product_name']
        indices = pd.Series(products.index, index=products)

        # Get the indices and similarity scores of products similar to the ones the user has already purchased
        similarity_scores = list(enumerate(cosine_sim_user[-1]))
        similarity_scores = [(i, score) for (i, score) in similarity_scores if i not in indices]

        # Sort the similarity scores in descending order
        similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

        # Get the indices of the top 5 most similar products
        top_products = [i[0] for i in similarity_scores[2:7]]

        # Get the names of the top 5 most similar products
        recommended_products = data.iloc[top_products]['product_name'].tolist()

        # Get the reasons for the recommendation
        score = [similarity_scores[i][1] for i in range(5)]

        # Get the original product IDs
        ID_products= data.iloc[top_products]['product_id'].tolist()

        # Create a DataFrame with the results
        results_data = pd.DataFrame({'ID_products': ID_products,
                                   'recommended product': recommended_products,
                                   'score recommendation': score})

        return results_data

    else:
        print("No products found.")
        return None

# %%
idprod= 111
target_product= data.loc[data['product_id_encoded'] == idprod, ['product_name','product_id']]
print('The target product is: ', target_product)
print('\n')
print('The most similar products are:')
recommend_products(data, idprod)
# Out:
# The target product is:                                             product_name  product_id
# 1127  Ikea 903.391.72 Polypropylene Plastic Solid Be...  B00SH18114
#
#
# The most similar products are:
#   ID_products                                recommended product  \
# 0  B00B3VFJY2  HUL Pureit Germkill kit for Advanced 23 L wate...
# 1  B078XFKBZL       Prestige Clean Home Water Purifier Cartridge
# 2  B0BJ966M5K  Aquadpure Copper + Mineral RO+UV+UF 10 to 12 L...
# 3  B07YC8JHMB  Aquasure From Aquaguard Amaze RO+UV+MTDS,7L st...
# 4  B0BNDRK886  IONIX Activated Carbon Faucet Water Filters Un...
#
#    score recommendation
# 0              1.000000
# 1              0.991896
# 2              0.840224
# 3              0.195492
# 4              0.160572
